# %% [markdown]
# Fine-tuned efficientnet
# high accuracy (0.9) but biased

# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from collections import Counter
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Dense, Dropout, GlobalAveragePooling2D,
                                     BatchNormalization)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.efficientnet_v2 import EfficientNetV2S, preprocess_input
from tensorflow.keras.callbacks import (ModelCheckpoint, EarlyStopping, ReduceLROnPlateau)
from tensorflow.keras.optimizers.schedules import CosineDecayRestarts

# ===========================================================
# 1. Parameters
# ===========================================================
IMG_SIZE    = (300, 300)
BATCH_SIZE  = 32
VAL_SPLIT   = 0.2
NUM_CLASSES = 5
EXTRACT_PATH = "dataset(5dishes)"  # <-- Update this to your dataset path

# ===========================================================
# 2. Augmentation
# ===========================================================
datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    validation_split=VAL_SPLIT,
    rotation_range=30,
    shear_range=0.25,
    zoom_range=(0.75, 1.25),
    width_shift_range=0.2,
    height_shift_range=0.2,
    channel_shift_range=20.0,
    brightness_range=[0.7, 1.3],
    horizontal_flip=True,
)

train_gen = datagen.flow_from_directory(
    os.path.join(EXTRACT_PATH, "train"),
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    subset="training",
    shuffle=True,
)

val_gen = datagen.flow_from_directory(
    os.path.join(EXTRACT_PATH, "validate"),
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    subset="validation",
    shuffle=False,
)

# ===========================================================
# 3. Class weights
# ===========================================================
class_weights = dict(
    enumerate(
        compute_class_weight("balanced",
                             classes=np.unique(train_gen.classes),
                             y=train_gen.classes)
    )
)

# ===========================================================
# 4. Focal loss with label smoothing
# ===========================================================
def focal_loss(alpha=1.0, gamma=2.0, label_smoothing=0.05, num_classes=5):
    alpha = tf.constant(alpha, dtype=tf.float32)
    def loss(y_true, y_pred):
        y_true = y_true * (1 - label_smoothing) + label_smoothing / num_classes
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
        cross_ce = -y_true * tf.math.log(y_pred)
        weight = alpha * tf.pow(1 - y_pred, gamma)
        return tf.reduce_sum(weight * cross_ce, axis=-1)
    return loss

# ===========================================================
# 5. Build model
# ===========================================================
lr_sched = CosineDecayRestarts(initial_learning_rate=1e-3,
                               first_decay_steps=5 * len(train_gen),
                               t_mul=2.0, m_mul=0.5)

def build_model(lr_sched):
    base = EfficientNetV2S(weights="imagenet",
                           include_top=False,
                           input_tensor=Input(shape=(*IMG_SIZE, 3)))
    base.trainable = False

    x = GlobalAveragePooling2D()(base.output)
    x = BatchNormalization()(x)
    x = Dense(512, activation="relu")(x)
    x = Dropout(0.5)(x)
    out = Dense(NUM_CLASSES, activation="softmax")(x)

    lr_sched = CosineDecayRestarts(initial_learning_rate=1e-3,
                                   first_decay_steps=5 * len(train_gen),
                                   t_mul=2.0, m_mul=0.5)

    model = Model(base.input, out)
    model.compile(optimizer=Adam(lr_sched), loss=focal_loss(alpha=1.0, gamma=2.0, label_smoothing=0.05, num_classes=NUM_CLASSES), metrics=["accuracy"])
    return model, base

model, base_model = build_model(lr_sched)
model.summary()

# ===========================================================
# 6. Callbacks
# ===========================================================
cbs = [
    ModelCheckpoint("best_effnetv2s_5vn.h5", monitor="val_accuracy",
                    save_best_only=True, mode="max", verbose=1),
    EarlyStopping(monitor="val_loss", patience=8,
                  restore_best_weights=True, verbose=1)
    # ReduceLROnPlateau(monitor="val_loss", factor=0.2,
    #                   patience=4, min_lr=1e-6, verbose=1),
]

# ===========================================================
# 7. Phase-1: frozen base
# ===========================================================
history1 = model.fit(train_gen,
                     validation_data=val_gen,
                     epochs=20,
                     class_weight=class_weights,
                     callbacks=cbs,
                     verbose=1)

# ===========================================================
# 8. Phase-2: fine-tune last 120 layers
# ===========================================================
for layer in base_model.layers[-120:]:
    layer.trainable = True

model.compile(optimizer=Adam(learning_rate=lr_sched), loss=focal_loss(alpha=1.0, gamma=2.0, label_smoothing=0.05, num_classes=NUM_CLASSES), metrics=["accuracy"])

history2 = model.fit(train_gen,
                     validation_data=val_gen,
                     epochs=25,
                     initial_epoch=len(history1.epoch),
                     class_weight=class_weights,
                     callbacks=cbs,
                     verbose=1)

# ===========================================================
# 9. Evaluation and plots
# ===========================================================
val_loss, val_acc = model.evaluate(val_gen, verbose=0)
print(f"\n🔎 Final validation accuracy: {val_acc:.2%}")

def plot_hist(*hists):
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    for h in hists:
        plt.plot(h.history["accuracy"], label="train")
        plt.plot(h.history["val_accuracy"], label="val")
    plt.title("Accuracy"); plt.grid(True); plt.legend()

    plt.subplot(1, 2, 2)
    for h in hists:
        plt.plot(h.history["loss"], label="train")
        plt.plot(h.history["val_loss"], label="val")
    plt.title("Loss"); plt.grid(True); plt.legend()
    plt.tight_layout(); plt.show()

plot_hist(history1, history2)
# Out:
# Found 2864 images belonging to 5 classes.
# Found 100 images belonging to 5 classes.
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 300, 300,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling           │ (None, 300, 300,  │          0 │ input_layer_1[0]… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv (Conv2D)  │ (None, 150, 150,  │        648 │ rescaling[0][0]   │
# │                     │ 24)               │            │                   │
# ...

# %%
# Save final model (optional, different from best checkpoint)
model.save("final_effnetv2s_5vn.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.applications.efficientnet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# === Load model ===
def focal_loss(alpha=1.0, gamma=2.0, label_smoothing=0.05, num_classes=5):
    alpha = tf.constant(alpha, dtype=tf.float32)
    def loss(y_true, y_pred):
        y_true = y_true * (1 - label_smoothing) + label_smoothing / num_classes
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
        cross_ce = -y_true * tf.math.log(y_pred)
        weight = alpha * tf.pow(1 - y_pred, gamma)
        return tf.reduce_sum(weight * cross_ce, axis=-1)
    return loss

model = load_model("final_effnetv2s_5vn.h5",
                   custom_objects={"loss": focal_loss(alpha=1.0, gamma=2.0, label_smoothing=0.05, num_classes=5)})

# === Prepare test data ===
IMG_SIZE = (300, 300)
BATCH_SIZE = 32
TEST_PATH = "dataset(5dishes)/test"  # <-- make sure this folder exists and has 5 subfolders (1 per class)

test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

test_gen = test_datagen.flow_from_directory(
    TEST_PATH,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False,
)

# === Predict ===
pred_probs = model.predict(test_gen)
pred_classes = np.argmax(pred_probs, axis=1)
true_classes = test_gen.classes
class_labels = list(test_gen.class_indices.keys())

# === Evaluate ===
accuracy = np.mean(pred_classes == true_classes)
print(f"Test Accuracy: {accuracy:.2%}")

# Optional: show classification report
from sklearn.metrics import classification_report
print(classification_report(true_classes, pred_classes, target_names=class_labels))
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Found 1026 images belonging to 5 classes.
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 44s 964ms/step
# Test Accuracy: 98.15%
#               precision    recall  f1-score   support
#
#      Banh mi       0.99      0.97      0.98       268
#     Banh xeo       0.97      0.97      0.97       235
#      Com tam       0.97      0.99      0.98       189
#     Goi cuon       0.98      0.99      0.99       172
#          Pho       0.99      0.99      0.99       162
#
#     accuracy                           0.98      1026
#    macro avg       0.98      0.98      0.98      1026
# weighted avg       0.98      0.98      0.98      1026

# %%
import os
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import load_model

# Load test set
datagen = ImageDataGenerator(rescale=1./255)

test_gen = datagen.flow_from_directory(
    os.path.join(EXTRACT_PATH, "test"),
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False
)

# Predict
preds = model.predict(test_gen, verbose=1)
pred_indices = np.argmax(preds, axis=1)

# Map indices to class names
index_to_class = {v: k for k, v in test_gen.class_indices.items()}

# Convert to label names
pred_labels = [index_to_class[i] for i in pred_indices]
true_labels = [index_to_class[i] for i in test_gen.classes]

# Print sample results
for i in range(10):
    print(f"True: {true_labels[i]}, Predicted: {pred_labels[i]}")

# Optionally: Evaluate performance
from sklearn.metrics import classification_report, confusion_matrix
print("\nClassification Report:")
print(classification_report(true_labels, pred_labels))

# Save the model
model.save("vietnamese_food_model.h5")
print("Model saved as vietnamese_food_model.h5")
# Out:
# Found 1026 images belonging to 5 classes.
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 26s 607ms/step
# /Users/nhuquynhtran/Downloads/Tensorflow Env (Latest)/tf219-env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/nhuquynhtran/Downloads/Tensorflow Env (Latest)/tf219-env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.applications.efficientnet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# === Load model ===
def focal_loss(alpha=1.0, gamma=2.0, label_smoothing=0.05, num_classes=5):
    alpha = tf.constant(alpha, dtype=tf.float32)
    def loss(y_true, y_pred):
        y_true = y_true * (1 - label_smoothing) + label_smoothing / num_classes
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
        cross_ce = -y_true * tf.math.log(y_pred)
        weight = alpha * tf.pow(1 - y_pred, gamma)
        return tf.reduce_sum(weight * cross_ce, axis=-1)
    return loss

model = load_model("final_effnetv2s_5vn.h5",
                   custom_objects={"loss": focal_loss(alpha=1.0, gamma=2.0, label_smoothing=0.05, num_classes=5)})

# === Prepare test data ===
IMG_SIZE = (300, 300)
BATCH_SIZE = 32
TEST_PATH = "dataset(5dishes)/test"  # <-- make sure this folder exists and has 5 subfolders (1 per class)

test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

test_gen = test_datagen.flow_from_directory(
    TEST_PATH,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False,
)

# === Predict ===
pred_probs = model.predict(test_gen)
pred_classes = np.argmax(pred_probs, axis=1)
true_classes = test_gen.classes
class_labels = list(test_gen.class_indices.keys())

# === Evaluate ===
accuracy = np.mean(pred_classes == true_classes)
print(f"Test Accuracy: {accuracy:.2%}")

# Optional: show classification report
from sklearn.metrics import classification_report
print(classification_report(true_classes, pred_classes, target_names=class_labels))
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Found 1026 images belonging to 5 classes.
# /Users/nhuquynhtran/Downloads/Tensorflow Env (Latest)/tf219-env/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 38s 890ms/step
# Test Accuracy: 98.15%
#               precision    recall  f1-score   support
#
#      Banh mi       0.99      0.97      0.98       268
#     Banh xeo       0.97      0.97      0.97       235
#      Com tam       0.97      0.99      0.98       189
#     Goi cuon       0.98      0.99      0.99       172
# ...

# %%
"""
Test EfficientNetV2-S model on the 5-dish test set
--------------------------------------------------
Assumptions
-----------
dataset(5dishes)/
├── train/      (used during training)
├── validate/   (used during training)
└── test/       (5 sub-folders, one per dish)

The file final_effnetv2s_5vn.h5 is in the current directory.
"""

import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.efficientnet_v2 import preprocess_input
from sklearn.metrics import classification_report, confusion_matrix

# ========== 1. Parameters ==========
IMG_SIZE     = (300, 300)
BATCH_SIZE   = 32
NUM_CLASSES  = 5
EXTRACT_PATH = "dataset(5dishes)"     # <- change if your path differs
MODEL_FILE   = "final_effnetv2s_5vn.h5"

# ========== 2. Re-create the custom loss ==========
def focal_loss(alpha=1.0, gamma=2.0, label_smoothing=0.05, num_classes=NUM_CLASSES):
    alpha = tf.constant(alpha, dtype=tf.float32)
    def loss(y_true, y_pred):
        y_true = y_true * (1 - label_smoothing) + label_smoothing / num_classes
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
        cross_ce = -y_true * tf.math.log(y_pred)
        weight = alpha * tf.pow(1 - y_pred, gamma)
        return tf.reduce_sum(weight * cross_ce, axis=-1)
    return loss

# ========== 3. Load the model ==========
model = load_model(
    MODEL_FILE,
    custom_objects={"loss": focal_loss(alpha=1.0, gamma=2.0,
                                       label_smoothing=0.05,
                                       num_classes=NUM_CLASSES)}
)
print("✅ Model loaded.")

# ========== 4. Prepare the test generator ==========
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

test_gen = test_datagen.flow_from_directory(
    os.path.join(EXTRACT_PATH, "test"),
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False
)

# ========== 5. Predict ==========
pred_probs   = model.predict(test_gen, verbose=1)
pred_indices = np.argmax(pred_probs, axis=1)
true_indices = test_gen.classes

# ===== 6. Decode indices to class names =====
idx_to_class = {v: k for k, v in test_gen.class_indices.items()}

# Predict raw probabilities from the model
raw_preds = model.predict(test_gen, verbose=1)

# Convert softmax outputs to predicted class indices
preds = np.argmax(raw_preds, axis=1)

# Mapping: class index -> class name
class_map = test_gen.class_indices
inv_class_map = {v: k for k, v in class_map.items()}

# Get true and predicted labels in human-readable form
true_labels = [inv_class_map[i] for i in test_gen.classes]
pred_labels = [inv_class_map[i] for i in preds]


# ========== 7. Report ==========
print("\nClassification report:")
print(classification_report(true_labels, pred_labels))

print("Confusion matrix (rows = true, cols = pred):")
print(confusion_matrix(true_labels, pred_labels))

# Optional: save raw predictions to CSV
# import pandas as pd
# df = pd.DataFrame({
#     "filename" : test_gen.filenames,
#     "true"     : true_labels,
#     "pred"     : pred_labels,
#     "prob_max" : pred_probs.max(axis=1)
# })
# df.to_csv("test_predictions.csv", index=False)
# print("Saved CSV: test_predictions.csv")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ✅ Model loaded.
# Found 1026 images belonging to 5 classes.
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 49s 1s/step
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 19s 562ms/step
#
# Classification report:
#               precision    recall  f1-score   support
#
#      Banh mi       0.99      0.97      0.98       268
#     Banh xeo       0.97      0.97      0.97       235
#      Com tam       0.97      0.99      0.98       189
#     Goi cuon       0.98      0.99      0.99       172
#          Pho       0.99      0.99      0.99       162
#
#     accuracy                           0.98      1026
#    macro avg       0.98      0.98      0.98      1026
# weighted avg       0.98      0.98      0.98      1026
#
# Confusion matrix (rows = true, cols = pred):
# [[260   3   4   1   0]
#  [  2 229   1   2   1]
#  [  0   2 187   0   0]
#  [  0   0   0 171   1]
# ...
